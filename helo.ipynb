# %%
import pandas as pd
import numpy as np

# Sample DataFrame with original column names (replace this with your actual DataFrame)
data = {
    'Date/Time': [1, 2, 3],
    'SO2': [10, 20, 30],
    'DATA CAP.': [100, 90, 80],
    'SO2 Avg': [15, 25, 35],
    'NO2': [40, 50, 60],
    'DATA CAP.': [100, 95, 85],
    'No2 Avg': [45, 55, 65],
    'O3': [70, 80, 90],
    'DATA CAP.': [100, 92, 89],
    'O3 8H Avg.': [75, 85, 95],
    'Daily Capture': [100, 80, 90],
    'O3 Daily average': [72, 82, 92],
    'O3 Daily average (NS)': [70, 80, 90],
    'CO': [10, 15, 20],
    'DATA CAP.': [100, 98, 96],
    'CO 8H Avg.': [12, 17, 22],
    'Daily Capture1': [100, 75, 85],
    'CO Daily average': [10, 15, 20],
    'PM10': [12, 14, 16],
    'DATA CAP.': [100, 97, 95],
    'PM10 Avg': [13, 15, 17],
    'PM2.5': [5, 7, 9],
    'DATA CAP.': [100, 99, 98],
    'PM2.5 Avg': [6, 8, 10],
    'Lower Ambient Temperature': [10, 12, 15],
    'Upper Ambient Temperature': [20, 25, 30],
    'Barometric Pressure': [1012, 1013, 1014],
    'RelativeHumidity': [50, 55, 60],
    'Wind Direction': [180, 190, 200],
    'Wind Speed': [5, 10, 15],
    'H2S': [0.1, 0.2, 0.3],
    'Toluene': [0.01, 0.02, 0.03],
    'O_Xylene': [0.1, 0.12, 0.15],
    'EthylBenzene': [0.2, 0.25, 0.3],
    'mp_xylene_': [0.03, 0.05, 0.07],
    'Benzene': [0.02, 0.04, 0.06],
    'CH4': [1, 1.5, 2],
    'NMHC': [3, 3.5, 4],
    'THC': [5, 5.5, 6],
    'Noise': [45, 50, 55],
}

df = pd.DataFrame(data)

# Mapping the original column names to new column names
column_mapping = {
    'SO2': 'SO2',
    'DATA CAP.': 'DATA CAP. (SO2)',
    'SO2 Avg': 'SO2 Avg',
    'NO2': 'NO2',
    'DATA CAP.1': 'DATA CAP. (NO2)',
    'No2 Avg': 'NO2 Avg',
    'O3': 'O3',
    'DATA CAP.2': 'DATA CAP. (O3)',
    'O3 8H Avg.': 'O3 8H Avg. (WHO)',
    'Daily Capture': 'Daily Capture (WHO)',
    'O3 Daily average': 'O3 Daily Average (WHO)',
    'O3 Daily average (NS)': 'O3 Daily Average (N/S)',
    'CO': 'CO',
    'DATA CAP.3': 'DATA CAP. (CO)',
    'CO 8H Avg.': 'CO 8H Avg.',
    'Daily Capture1': 'Daily Capture (CO)',
    'CO Daily average': 'CO Daily Average',
    'PM10': 'PM10',
    'DATA CAP.4': 'DATA CAP. (PM10)',
    'PM10 Avg': 'PM10 Avg',
    'PM2.5': 'PM2.5',
    'DATA CAP.5': 'DATA CAP. (PM2.5)',
    'PM2.5 Avg': 'PM2.5 Avg',
    'Lower Ambient Temperature': 'Lower Ambient Temperature',
    'Upper Ambient Temperature': 'Upper Ambient Temperature',
    'Barometric Pressure': 'Barometric Pressure',
    'RelativeHumidity': 'Relative Humidity',
    'Wind Direction': 'Wind Direction',
    'Wind Speed': 'Wind Speed',
    'H2S': 'H2S',
    'Toluene': 'Toluene',
    'O_Xylene': 'O_Xylene',
    'EthylBenzene': 'Ethylbenzene',
    'mp_xylene_': 'mp_xylene_',
    'Benzene': 'Benzene',
    'CH4': 'CH4',
    'NMHC': 'NMHC',
    'THC': 'THC',
    'Noise': 'Noise'
}

df.columns
# Out:
# Index(['Date/Time', 'SO2', 'DATA CAP.', 'SO2 Avg', 'NO2', 'No2 Avg', 'O3',
#        'O3 8H Avg.', 'Daily Capture', 'O3 Daily average',
#        'O3 Daily average (NS)', 'CO', 'CO 8H Avg.', 'Daily Capture1',
#        'CO Daily average', 'PM10', 'PM10 Avg', 'PM2.5', 'PM2.5 Avg',
#        'Lower Ambient Temperature', 'Upper Ambient Temperature',
#        'Barometric Pressure', 'RelativeHumidity', 'Wind Direction',
#        'Wind Speed', 'H2S', 'Toluene', 'O_Xylene', 'EthylBenzene',
#        'mp_xylene_', 'Benzene', 'CH4', 'NMHC', 'THC', 'Noise'],
#       dtype='object')

# %%
df
# Out:
#    Date/Time  SO2  DATA CAP.  SO2 Avg  NO2  DATA CAP.1  No2 Avg  O3  \
# 0          1   10        100       15   40         100       45  70
# 1          2   20         90       25   50          95       55  80
# 2          3   30         80       35   60          85       65  90
#
#    DATA CAP.2  O3 8H Avg.  ...  H2S  Toluene  O_Xylene  EthylBenzene  \
# 0         100          75  ...  0.1     0.01      0.10          0.20
# 1          92          85  ...  0.2     0.02      0.12          0.25
# 2          89          95  ...  0.3     0.03      0.15          0.30
#
#    mp_xylene_  Benzene  CH4  NMHC  THC  Noise
# 0        0.03     0.02  1.0   3.0  5.0     45
# 1        0.05     0.04  1.5   3.5  5.5     50
# 2        0.07     0.06  2.0   4.0  6.0     55
#
# [3 rows x 40 columns]
